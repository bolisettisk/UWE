# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Importing spotify_songs dataset to dat variable

# %%
dat = pd.read_csv("spotify_songs.csv")

# %%
dat.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# ...

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  object
#  1   track_name                32828 non-null  object
#  2   track_artist              32828 non-null  object
#  3   track_popularity          32833 non-null  int64
#  4   track_album_id            32833 non-null  object
#  5   track_album_name          32828 non-null  object
#  6   track_album_release_date  32833 non-null  object
#  7   playlist_name             32833 non-null  object
#  8   playlist_id               32833 non-null  object
#  9   playlist_genre            32833 non-null  object
#  10  playlist_subgenre         32833 non-null  object
#  11  danceability              32833 non-null  float64
#  12  energy                    32833 non-null  float64
# ...

# %% [markdown]
# Non-Null Count of some of the variables doesn't match the RangeIndex. They clearly contain null values

# %%
dat[dat["track_name"].isna()]
# Out:
#                      track_id track_name track_artist  track_popularity  \
# 8151   69gRFGOWY9OMpFJgFol1u0        NaN          NaN                 0
# 9282   5cjecvX0CmC9gK0Laf5EMQ        NaN          NaN                 0
# 9283   5TTzhRSWQS4Yu8xTgAuq6D        NaN          NaN                 0
# 19568  3VKFip3OdAvv4OfNTgFWeQ        NaN          NaN                 0
# 19811  69gRFGOWY9OMpFJgFol1u0        NaN          NaN                 0
#
#                track_album_id track_album_name track_album_release_date  \
# 8151   717UG2du6utFe7CdmpuUe3              NaN               2012-01-05
# 9282   3luHJEPw434tvNbme3SP8M              NaN               2017-12-01
# 9283   3luHJEPw434tvNbme3SP8M              NaN               2017-12-01
# 19568  717UG2du6utFe7CdmpuUe3              NaN               2012-01-05
# 19811  717UG2du6utFe7CdmpuUe3              NaN               2012-01-05
#
#             playlist_name             playlist_id playlist_genre  ... key  \
# ...

# %%
dat[dat["track_name"].isna()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 8151 to 19811
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  5 non-null      object
#  1   track_name                0 non-null      object
#  2   track_artist              0 non-null      object
#  3   track_popularity          5 non-null      int64
#  4   track_album_id            5 non-null      object
#  5   track_album_name          0 non-null      object
#  6   track_album_release_date  5 non-null      object
#  7   playlist_name             5 non-null      object
#  8   playlist_id               5 non-null      object
#  9   playlist_genre            5 non-null      object
#  10  playlist_subgenre         5 non-null      object
#  11  danceability              5 non-null      float64
#  12  energy                    5 non-null      float64
# ...

# %% [markdown]
# There are 5 rows with null values. Removing null entries

# %%
dat_clean = dat[dat["track_name"].notna()]

# %%
dat_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32828 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32828 non-null  object
#  1   track_name                32828 non-null  object
#  2   track_artist              32828 non-null  object
#  3   track_popularity          32828 non-null  int64
#  4   track_album_id            32828 non-null  object
#  5   track_album_name          32828 non-null  object
#  6   track_album_release_date  32828 non-null  object
#  7   playlist_name             32828 non-null  object
#  8   playlist_id               32828 non-null  object
#  9   playlist_genre            32828 non-null  object
#  10  playlist_subgenre         32828 non-null  object
#  11  danceability              32828 non-null  float64
#  12  energy                    32828 non-null  float64
# ...

# %%
dat_clean.head(2)
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
#
#   track_artist  track_popularity          track_album_id  \
# 0   Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1     Maroon 5                67  63rPSO264uRjW1X5E6cWv6
#
#                                     track_album_name track_album_release_date  \
# 0  I Don't Care (with Justin Bieber) [Loud Luxury...               2019-06-14
# 1                    Memories (Dillon Francis Remix)               2019-12-13
#
#   playlist_name             playlist_id playlist_genre  ... key  loudness  \
# 0     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   6    -2.634
# 1     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...  11    -4.969
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %%
dat_clean.columns
# Out:
# Index(['track_id', 'track_name', 'track_artist', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms'],
#       dtype='object')

# %%
dsort = dat_clean.groupby(["track_artist"], as_index=False).mean("track_popularity").sort_values("track_popularity", ascending=False)

# %%
dsort.head()
# Out:
#         track_artist  track_popularity  danceability    energy        key  \
# 9735   Trevor Daniel         97.000000      0.784000  0.430000  10.000000
# 10242            Y2K         91.000000      0.843000  0.391000   2.000000
# 2601     Don Toliver         90.714286      0.669429  0.639000   5.428571
# 7959     Roddy Ricch         88.210526      0.857684  0.564316   7.157895
# 2209          DaBaby         87.857143      0.796286  0.719143   6.214286
#
#        loudness      mode  speechiness  acousticness  instrumentalness  \
# 9735  -8.756000  0.000000     0.036400      0.123000      0.000000e+00
# 10242 -7.899000  1.000000     0.084500      0.181000      0.000000e+00
# 2601  -4.916571  0.142857     0.102857      0.514429      7.388571e-04
# 7959  -7.594895  0.210526     0.152389      0.092632      2.221053e-05
# 2209  -4.330286  0.571429     0.333993      0.122871      4.171429e-07
#
#        liveness   valence       tempo    duration_ms
# ...

# %%
dsort = dsort[dsort["track_popularity"] > 80]

# %%
dsort.head()
# Out:
#         track_artist  track_popularity  danceability    energy        key  \
# 9735   Trevor Daniel         97.000000      0.784000  0.430000  10.000000
# 10242            Y2K         91.000000      0.843000  0.391000   2.000000
# 2601     Don Toliver         90.714286      0.669429  0.639000   5.428571
# 7959     Roddy Ricch         88.210526      0.857684  0.564316   7.157895
# 2209          DaBaby         87.857143      0.796286  0.719143   6.214286
#
#        loudness      mode  speechiness  acousticness  instrumentalness  \
# 9735  -8.756000  0.000000     0.036400      0.123000      0.000000e+00
# 10242 -7.899000  1.000000     0.084500      0.181000      0.000000e+00
# 2601  -4.916571  0.142857     0.102857      0.514429      7.388571e-04
# 7959  -7.594895  0.210526     0.152389      0.092632      2.221053e-05
# 2209  -4.330286  0.571429     0.333993      0.122871      4.171429e-07
#
#        liveness   valence       tempo    duration_ms
# ...

# %%
dat_clean = dat_clean[dat_clean["track_artist"].isin(dsort["track_artist"])]

# %%
sns.set(rc={'figure.figsize':(25,10)})
sns.barplot(data=dat_clean, x="track_artist", y="track_popularity")
# Out:
# <AxesSubplot:xlabel='track_artist', ylabel='track_popularity'>

# %%
sns.set(rc={'figure.figsize':(25,15)})
sns.boxplot(data=dat_clean, x="track_artist", y="track_popularity")
# Out:
# <AxesSubplot:xlabel='track_artist', ylabel='track_popularity'>

# %%
sns.set(rc={'figure.figsize':(30,5)})
sns.histplot(dat_clean["track_artist"])
# Out:
# <AxesSubplot:xlabel='track_artist', ylabel='Count'>

# %%
sns.barplot(x = "playlist_genre", y = "danceability", data = data_ES, hue="track_artist")
# Out:
# <AxesSubplot:xlabel='playlist_genre', ylabel='danceability'>
